# %%
pip install praw
# Out:
# ...
#      |████████████████████████████████| 153kB 5.3MB/s
# ...
#      |████████████████████████████████| 204kB 5.8MB/s
# ...

# %%
import praw
import pandas as pd
import os
import re
import requests
import time
import pickle
import calendar
import datetime as dt

#Display every call in output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from google.colab import drive
drive.mount('/content/gdrive')
path = 'grive/My Drive/Colab Notebooks/License/Data'
# Out:
# Mounted at /content/gdrive

# %%
pip install stackapi
# Out:
# ...
#   Created wheel for stackapi: filename=StackAPI-0.1.12-cp36-none-any.whl size=5669 sha256=8966646c89789ab8d39c87d5abab103bffc3f269df1db5c99f251d7633a62aac
#   Stored in directory: /root/.cache/pip/wheels/16/bf/a5/56362daf788c5ce88244796b26d3e7d6fec649f5e77aff694c
# Successfully built stackapi
# ...

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow',2.2)

#date from begining of January for demo purposes

questions = SITE.fetch('questions', fromdate=1609459200, todate=1611619200, tagged='java')

titles = []

##questions

for item in questions['items']:
  title = item['title']
  titles.append(str(title))

titles
# Out:
# ['Error creating bean in Spring boot in CentOS',
#  'Trying to pull logs from Github using Java JGit',
#  'JDBC Driver for TigerGraph DB',
#  'How to add a new property to a Json object while iterating',
#  'Unable to find method &#39;org.gradle.api.reporting.internal.TaskReportContainer.&lt;init&gt;(Ljava/lang/Class;Lorg/gradle/api/Task;)V&#39;',
#  'Does Java assume type based on result?',
#  'Java client, C# server, how to handle receiving a list',
#  'Can we load .fxml file in BlueJ IDE?',
#  'Unable to display the data fetch from the OBD scanner',
#  'How to capitalize first letter and lowercase the rest while keeping the word capital if it is in fully uppercase - java',
#  'Execute dependent commands on unix host with JSch',
#  'Implementing SSH shell terminal in webapp using JSch',
#  'Connect Azue SQL Database in Lnux Android Studio',
#  'org.artofsolving.jodconverter.office.OfficeManager is not initializing in wicket',
# ...

# %%
len(titles)
# Out:
# 500

# %%
my_question = "How to call a store procedure?"
